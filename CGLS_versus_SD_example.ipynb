# %% [markdown]
# ### Steepest descent (SD) vs the Conjugate Gradient for Least-Squares method (CGLS)
#
# - We first define an linear operator $A$ (a matrix)
# - We compute $y = Ax$ and then find ${\hat x}$ that minimized the quadratic cost function $J = \|Ax-y\|_2^2$
# - The minimum is computed via SD and CGLS  methods
# - $x$ is a vector of two elements  $x=[x_1,x_2]^T$ in order to plot the solution at each step of the CGLS and SD methods

# %%
using Random, LinearAlgebra, PyPlot

# %%
# Get a matrix A that leads to a cost function with an elongated valley 

rng = MersenneTwister(12724);
A = rand(rng,130,2)*2.0.-1.0; 
(U,S,V) = svd(A); S[1]=1.0; S[2]=0.4; A= U*diagm(S)*V;
x = [0.2,0.2]; y = A*x; x0 = [1.0,-1.5]

# Minimize J = |Ax-y|_2^2

x1, p1 = cg_ls(A,x0,y,2 )           # Minimize cost via CGLS 
x2, p2 =    sd(A,x0,y,25)           # Minimize cost via SD 

x1, x2, J = Cost(A,y)               # Compute cost function in a grid 

close("all")
subplot(221);
c = 10.0.^collect(-2:.4:3)

contour(x1,x2,J,c)
plot(p1[:,1],p1[:,2])
plot(p1[:,1],p1[:,2],"."); xlabel(L"$x_1$"); ylabel(L"x_2")
title("Conjugate Gradient method")

subplot(222);
contour(x1,x2,J,c)
plot(p2[:,1],p2[:,2],"-")
plot(p2[:,1],p2[:,2],"."); xlabel(L"$x_1$"); ylabel(L"x_2")
title("Steepest Descent method")

tight_layout()
savefig("./figs/cgls_vs_sd.png")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
"""
Compute cost J = |A x - y|_2^2 for the problem with two unknows 
"""
function Cost(A,y)
    
    (N,M)=size(A);
    L = 40

    x1 = 0.04*[k for k in -L:L]
    x2 = 0.05*[k for k in -L:L]
  

    J = zeros(2*L+1,2*L+1)
    
    for i1=1:2*L+1
        for i2=1:2*L+1
            x = vcat(x1[i1] ,x2[i2] )
            e=A*x-y
            J[i2,i1] = e'*e
        end
    end

    return x1,x2,J

end
# Out:
# Cost

# %%
"""
Steepest descent to solve x = argmin_x { ||A x - y ||_2^2 }, I also
save the solution path 
"""
function sd(A,x0,y,max_iter)

    (N,M) = size(A)
    M = length(x0)
    x = x0
    path = zeros(max_iter+1,M)
    path[1,:] .= x0
    
    e = A*x0-y
        ee = sum(e.^2)

k=1;
    while ee>0.0001 
        e = A*x-y
        ee = sum(e.^2)
        grad=A'*e
        u = A*grad
        step = (u'*e)/(u'*u)
        x = x - step*grad
    path[k+1,:] .=x
    k=k+1
    end
   
    return x,path[1:k-1,:]
end
# Out:
# sd

# %%
"""
CGLS Method for solving x = argmin_x { ||A x - y ||_2^2 }
Saves the solution path to ilustrate the method.
"""
function  cg_ls(A,x0,y,max_iter)
    
    
    (N,M) = size(A) 
    
    # Initialization
    
    x = x0
    s = y-A*x
    p = A'*s
    r = p
    q = A*p
    old = r'*r
    M = length(x0)
    path = zeros(max_iter+1,M)
    
    path[1,:] .= x0
   
    
    for k=1:max_iter
        alpha = r'*r/(q'*q)
        x = x + alpha*p
        path[k+1,:] .= x
        s = s - alpha*q
        r = A'*s
        new = r'*r
        beta = new/old
        old = new
        p = r + beta*p
        q = A*p
    end
    
    return x, path
end
# Out:
# cg_ls
