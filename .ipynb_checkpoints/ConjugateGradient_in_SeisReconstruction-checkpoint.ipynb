# %% [markdown]
# # ConjugateGradients.jl  from SeisReconstruction
#
# ## https://github.com/SeismicJulia/SeisReconstruction.jl
#
#
# The Conjugate Gradient (CG) algorithm used by SeisReconstruction is named ConjugateGradients.jl, and below I show how to use it  with implicit-form operators. Before addressing implicit-form computations, we must ensure that CG works. Therefore, I will first compare CG solutions to the closed-form solutions obtained by differentiating the quadratic cost function.
#
#
# CG is a semi-iterative method used to solve linear systems of equations:
#
# $$A x \approx y$$
#
# where one can find $x$ by minimizing the following cost function
#
# $$J = \| A x - y \|_2^2 + \mu \|x \|$$
#
# In the latter, $\mu$ is a regularization parameter used to guarantee the stability of the inversion. Our CG algorithm is a  solver that requires $A$ and $A^T$, $\mu$,
# and of course the data $y$, then it finds the minimizer of $J$.
#
#
# Closed-form solutions: The closed-form solutions that we will use to test the CG algorithms
# are the following
#
# $$x_{dls} = ( A'A + \mu I)^{-1} A'y$$
#
# and
# $$x_{mn} = A'(AA' + \mu I)^{-1} y$$
#
# which are the equations we used for over-determined systems and under-determined systems, respectively. In my first lecture I  showed that the two solutions are equivalent provided that $\mu>0$ and both can be used
# for under and over-determined problems. However, for the over-determined problem, $A'A$ is smaller
# than $AA'$ and for the underdetermined problem, $AA'$ is smaller than $A'A$. Hence, we
# prefer to use $x_{dls}$ for the over-determined problem and $x_{mn}$ for the under-determined problem.
#
# CG does not care whether the problem is under or over, and as I will show, it will return the solution
# you would have computed with the explicit (closed-form) solution but in a series of steps (iterations).
# In each iteration, CG only needs to know how to apply $A[.]$ and $A^T[.]$ as linear operators.

# %%
using PyPlot, SeisReconstruction, LinearAlgebra, Printf, SeisPlot, FFTW, SeisProcessing

# %% [markdown]
# ### Problem 1: Overdetermined

# %%
M = 10
N = 20
x = ones(M)
A = randn(N,M)

y = MatrixMultiplyOp(x,false;matrix=A)

 operators = [MatrixMultiplyOp]
parameters = [Dict(:matrix=>A)]

μ = 4.0

xcg,cost =  ConjugateGradients(y, operators, parameters; Niter=M, mu=μ, tol=1.0e-5)

I = diagm(0 => ones(M))

xan = (A'*A + μ*I)\(A'*y)         # Closed-form least-squares solution with regularization

error = sum((xan-xcg).^2)

@printf("l2 Error norm between CG and closed-form solution = %g", error)
# Out:
# tolerance reached, ending at iteration 10
# l2 Error norm between CG and closed-form solution = 2.17472e-16

# %% [markdown]
# ### Problem 2: Underdetermined

# %%
M = 20
N = 10
x = ones(M)
A = randn(N,M)

y = MatrixMultiplyOp(x, false; matrix=A)

 operators = [MatrixMultiplyOp]
parameters = [Dict(:matrix=>A)]

μ = 4.0

xcg,cost =  ConjugateGradients(y,operators, parameters; Niter=M, mu=μ, tol=1.0e-5)

I = diagm(0 => ones(N))

xan = A'*((A*A' + μ*I)\y)        # Closed-form minimum norm solution with regularization

error = sum((xan-xcg).^2)

@printf("l2 Error norm between CG and closed-form solution = %g\n", error)
# Out:
# tolerance reached, ending at iteration 10
# l2 Error norm between CG and closed-form solution = 4.48885e-13

# %% [markdown]
# ### Problem 3

# %% [markdown]
# ## This is a more general problem where I evaluate the parabolic Radon transform as the solution of an implicit-form linear inverse problem

# %%
# Inverse problem crime to create a group of parabolic moveout events
 dh = 4.
 h0 = 0.
 h = collect(0:1:90)*dh
 dp = 0.03 
 p = collect(-30:1:30)*dp
 p0 = p[1]

 Par_R = Dict(:h=>h,:p=>p,:dt=>0.004,:transf=>"parab")
 m = zeros(200,length(p))
    
    m[40,50]= 1.0
    m[100,23]=-1.0
    m[150,31]=-1.0
    m[140,35]=1.0

wave = Ricker(dt=0.004,f0=40)
Par_W = Dict(:wavelet=>wave)
    
# compute the data  d = W R m = L m

  d  = Operator_Conv(SeisRadon_tx(m,false;Par_R...),false;Par_W...)

# compute the adjoint ma = R'W' d

  ma = SeisRadon_tx(Operator_Conv(d,true;Par_W...),true; Par_R...);

# Damped least-squares solution via CG

  mcg,cost =  ConjugateGradients(d, [Operator_Conv, SeisRadon_tx],[Par_W,Par_R]; Niter=20, mu=0.00001, tol=1.0e-5)

# Prediction of the data from Radon panel

  dpred = Operator_Conv(SeisRadon_tx(mcg,false;Par_R...),false;Par_W...);


subplot(221); SeisPlotTX(d,    dy=0.004, ox=h0, dx=dh, cmap="seismic",fignum=1,pclip=100,title="Data");colorbar()

subplot(222); SeisPlotTX(ma,   dy=0.004, ox=p0, dx=dp, cmap="seismic",fignum=1,pclip=100,title="Adjoint");colorbar()

subplot(223); SeisPlotTX(mcg,  dy=0.004, ox=p0, dx=dp, cmap="seismic",fignum=1,pclip=100,title="Inversion");colorbar()

subplot(224); SeisPlotTX(dpred,dy=0.004, ox=h0, dx=dh, cmap="seismic",fignum=1,pclip=100,title="Prediction");colorbar()

tight_layout()
# Out:
# Figure(PyObject <Figure size 640x480 with 8 Axes>)

# %%
plot(cost)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x2a397cf70>

# %%
function SeisRadon_tx(In,adj;h=ones(10),p=ones(10),dt=0.004,transf="parab")
   
   
    np = length(p);
    nh = length(h);

    if (adj)
       d = In
       (nt, nh) = size(d)
       m = zeros(nt,np)
else
       m = In
       (nt, np) = size(m)
       d = zeros(nt,nh)
end



   tmax = (nt-1)*dt;
   tau = collect(0:1:nt-1)*dt;


     for itau = 1:1:nt
       for ih = 1:nh
        for ip = 1:np
           if cmp(transf,"parab")==0 ;
            hmax = maximum(abs.(h));
            t=tau[itau]+ (h[ih]/hmax)^2*p[ip];
         elseif cmp(transf,"linear")==0;
            t=tau[itau] + (h[ih]*p[ip]);
         elseif cmp(transf,"hyperb")==0;
            t=sqrt(tau[itau]^2 + (h[ih]^2/p[ip]^2));
         end
          if t>0 && t<tmax
            it    = t/dt+1;
            it1   = floor(Int,it);
            it2   = it1 + 1;
            alpha = it  - it1;

               if (adj) 
                    m[itau,ip] = m[itau,ip] + (1-alpha) * d[it1,ih] + alpha*d[it2,ih];
                  else 
                    d[it1,ih] = d[it1,ih]+ (1-alpha) * m[itau,ip];
                    d[it2,ih] = d[it2,ih] +    alpha * m[itau,ip];
               end

        end
       end
      end
   end


   if (adj) 
      Out = m
    else 
      Out = d;
   end

   return Out
end
# Out:
# SeisRadon_tx (generic function with 2 methods)

# %%
"""
Operator_Conv: Convolution of traces with a wavelet when adj=false
               Crosscorrelation of traces a wavelet when adj=true 
"""

function Operator_Conv(In,adj;wavelet=ones(10))

   nt,nx = size(In)
   nf = nextpow(2,nt)
   nw = length(wavelet)
   W = fft(vcat(wavelet,zeros(nf-nw))) 
   Out = zeros(nt,nx)

if (adj) 
  for k = 1:nx
    aux = In[:,k];  
    Aux = fft(vcat(aux,zeros(nf-nt))).*conj.(W); 
    tmp = real.(ifft(Aux))
    Out[:,k]  = tmp[1:nt] 
  end
else
  for k = 1:nx
    aux = In[:,k];  
    Aux = fft(vcat(aux,zeros(nf-nt))).*(W); 
    tmp = real.(ifft(Aux))
    Out[:,k]  = tmp[1:nt] 
  end
  end

return Out
end
# Out:
# Operator_Conv (generic function with 1 method)

# %%
size(p)
# Out:
# (61,)
